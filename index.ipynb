# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv("heroes_information.csv")
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
heroes_df = pd.read_csv("heroes_information.csv", index_col = 0)      

heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
publisher is missing 15 values
"""
# Out:
# '\npublisher is missing 15 values\n'

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col = 0)

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
drop row with .dropna @ publisher
"""
# Out:
# '\ndrop row with .dropna @ publisher\n'

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
#df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
heroes_clean = heroes_df.dropna(subset = ['Publisher'], inplace = True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# IDW Publishing         4
# ABC Studios            4
# Icon Comics            4
# Shueisha               4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# South Park             1
# J. K. Rowling          1
# Titan Books            1
# Hanna-Barbera          1
# Microsoft              1
# Rebellion              1
# J. R. R. Tolkien       1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
marvel and dc both listed twice
"""
# Out:
# '\nmarvel and dc both listed twice\n'

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here

heroes_df['Publisher'] = heroes_df['Publisher'].replace("Marvel", "Marvel Comics")


heroes_df['Publisher']
# Out:
# 0          Marvel Comics
# 1      Dark Horse Comics
# 2              DC Comics
# 3          Marvel Comics
# 4          Marvel Comics
#              ...
# 729        Marvel Comics
# 730        Marvel Comics
# 731         George Lucas
# 732            DC Comics
# 733            DC Comics
# Name: Publisher, Length: 719, dtype: object

# %%
heroes_df['Publisher'] = heroes_df['Publisher'].replace(" DC Comics", "DC Comics")

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Star Trek              6
# HarperCollins          6
# Team Epic TV           5
# SyFy                   5
# Icon Comics            4
# Shueisha               4
# IDW Publishing         4
# ABC Studios            4
# Wildstorm              3
# Sony Pictures          2
# J. K. Rowling          1
# South Park             1
# Titan Books            1
# Hanna-Barbera          1
# Microsoft              1
# Rebellion              1
# J. R. R. Tolkien       1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
heroes_df.keys()
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
powers_df.keys()
# Out:
# Index(['3-D Man', 'A-Bomb', 'Abe Sapien', 'Abin Sur', 'Abomination', 'Abraxas',
#        'Absorbing Man', 'Adam Monroe', 'Adam Strange', 'Agent Bob',
#        ...
#        'Wonder Man', 'Wonder Woman', 'X-23', 'X-Man', 'Yellowjacket',
#        'Yellowjacket II', 'Ymir', 'Yoda', 'Zatanna', 'Zoom'],
#       dtype='object', length=667)

# %%
# Replace None with appropriate text
"""
name is shared key
"""
# Out:
# '\nname is shared key\n'

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
powers_df.T
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# 3-D Man             True                False               False
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 3-D Man                          False            False       False    False
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# 3-D Man                      False   False         False  ...         False
# A-Bomb                       False   False         False  ...         False
# Abe Sapien                   False   False         False  ...         False
# Abin Sur                     False   False         False  ...         False
# Abomination                  False   False         False  ...         False
# ...                            ...     ...           ...  ...           ...
# Yellowjacket II              False    True         False  ...         False
# Ymir                         False   False         False  ...         False
# Yoda                         False   False          True  ...         False
# Zatanna                      False   False         False  ...         False
# Zoom                         False   False         False  ...         False
#
#                  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 3-D Man                    False       False             False        False
# A-Bomb                     False       False             False        False
# Abe Sapien                 False       False             False        False
# Abin Sur                   False       False             False        False
# Abomination                False       False             False        False
# ...                          ...         ...               ...          ...
# Yellowjacket II            False       False             False        False
# Ymir                       False       False             False        False
# Yoda                       False       False             False        False
# Zatanna                    False       False             False        False
# Zoom                       False       False             False        False
#
#                  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 3-D Man                  False                  False          False
# A-Bomb                   False                  False          False
# Abe Sapien               False                  False          False
# Abin Sur                 False                  False          False
# Abomination              False                  False          False
# ...                        ...                    ...            ...
# Yellowjacket II          False                  False          False
# Ymir                     False                  False          False
# Yoda                     False                  False          False
# Zatanna                  False                  False          False
# Zoom                     False                  False          False
#
#                  Omnipresent  Omniscient
# 3-D Man                False       False
# A-Bomb                 False       False
# Abe Sapien             False       False
# Abin Sur               False       False
# Abomination            False       False
# ...                      ...         ...
# Yellowjacket II        False       False
# Ymir                   False       False
# Yoda                   False       False
# Zatanna                False       False
# Zoom                   False       False
#
# [667 rows x 167 columns]

# %%
# Your code here (create more cells as needed)
heroes_and_powers_df = heroes_df.merge(powers_df.T, left_on = 'name', right_index = True)

len(heroes_and_powers_df)
# Out:
# 647

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [647 rows x 178 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                  name  Gender Eye color   Race        Hair color  Height  \
# 169         Chameleon    Male         -      -                 -   -99.0
# 188  Crimson Crusader    Male      blue      -  Strawberry Blond   -99.0
# 419              Luna  Female         -  Human                 -   -99.0
# 364         JJ Powell    Male         -      -                 -   -99.0
# 712         Weapon XI    Male         -      -                 -   -99.0
#
#          Publisher Skin color Alignment  Weight  ...  Reality Warping  \
# 169      DC Comics          -       bad   -99.0  ...            False
# 188  Marvel Comics          -      good   -99.0  ...            False
# 419  Marvel Comics          -      good   -99.0  ...            False
# 364    ABC Studios          -      good   -99.0  ...            False
# 712  Marvel Comics          -       bad   -99.0  ...            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 169       False             False        False          False
# 188       False             False        False          False
# 419       False             False        False          False
# 364       False             False        False          False
# 712       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  \
# 169                  False          False        False       False
# 188                  False          False        False       False
# 419                  False          False        False       False
# 364                  False          False        False       False
# 712                  False          False        False       False
#
#      Power Count
# 169            1
# 188            4
# 419            1
# 364            1
# 712            7
#
# [5 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 5     193.0      Marvel Comics          -       bad   122.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# ..               ...         ...               ...          ...
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# ..             ...                    ...            ...          ...
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# ..          ...          ...
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [484 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
heroes_and_powers_df.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight',
#        ...
#        'Reality Warping', 'Odin Force', 'Symbiote Costume', 'Speed Force',
#        'Phoenix Force', 'Molecular Dissipation', 'Vision - Cryo',
#        'Omnipresent', 'Omniscient', 'Power Count'],
#       dtype='object', length=178)

# %%
# Your code here (create more cells as needed)
question_3_df = heroes_and_powers_df.copy()
question_3_df = question_3_df[
    (question_3_df['Publisher'] == 'Marvel Comics') | 
    (question_3_df['Publisher'] == 'DC Comics')]      
# Superpower Name = powers_ds.index

relevant_cols = list(powers_df.index)
relevant_cols.append('Publisher')
question_3_df = question_3_df[relevant_cols]
question_3_df
# Out:
#      Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0      False                 True               False                  False
# 2      False                False                True                  False
# 3      False                 True               False                  False
# 4      False                False               False                   True
# 5      False                False               False                  False
# ..       ...                  ...                 ...                    ...
# 728    False                False               False                  False
# 729    False                False               False                  False
# 730    False                False               False                  False
# 732    False                False               False                  False
# 733    False                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# 5               True        True    False               True   False
# ..               ...         ...      ...                ...     ...
# 728            False       False    False              False   False
# 729            False       False    False              False    True
# 730             True        True    False              False   False
# 732            False       False    False              False   False
# 733            False       False    False              False   False
#
#      Danger Sense  ...  Reality Warping  Odin Force  Symbiote Costume  \
# 0           False  ...            False       False             False
# 2           False  ...            False       False             False
# 3           False  ...            False       False             False
# 4           False  ...            False       False             False
# 5           False  ...            False       False             False
# ..            ...  ...              ...         ...               ...
# 728         False  ...            False       False             False
# 729         False  ...            False       False             False
# 730         False  ...            False       False             False
# 732         False  ...            False       False             False
# 733         False  ...            False       False             False
#
#      Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 0          False          False                  False          False
# 2          False          False                  False          False
# 3          False          False                  False          False
# 4          False          False                  False          False
# 5          False          False                  False          False
# ..           ...            ...                    ...            ...
# 728        False          False                  False          False
# 729        False          False                  False          False
# 730        False          False                  False          False
# 732        False          False                  False          False
# 733        False          False                  False          False
#
#      Omnipresent  Omniscient      Publisher
# 0          False       False  Marvel Comics
# 2          False       False      DC Comics
# 3          False       False  Marvel Comics
# 4          False       False  Marvel Comics
# 5          False       False  Marvel Comics
# ..           ...         ...            ...
# 728        False       False  Marvel Comics
# 729        False       False  Marvel Comics
# 730        False       False  Marvel Comics
# 732        False       False      DC Comics
# 733        False       False      DC Comics
#
# [537 rows x 168 columns]

# %%
question_3_df = question_3_df.groupby('Publisher').sum().T

# %%
question_3_df.index.name = 'Superpower Name'
question_3_df.reset_index(inplace = True)

# %%
question_3_df.columns.name = None

# %%
question_3_df
# Out:
#            Superpower Name  DC Comics  Marvel Comics
# 0                  Agility         71            126
# 1      Accelerated Healing         51            100
# 2       Lantern Power Ring         11              0
# 3    Dimensional Awareness          7             16
# 4          Cold Resistance         15             25
# ..                     ...        ...            ...
# 162          Phoenix Force          0              1
# 163  Molecular Dissipation          1              0
# 164          Vision - Cryo          1              0
# 165            Omnipresent          0              1
# 166             Omniscient          0              1
#
# [167 rows x 3 columns]

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common
# Out:
#    Superpower Name  Marvel Comics
# 17  Super Strength            204
# 5       Durability            154
# 25         Stamina            150
# 30     Super Speed            137
# 0          Agility            126

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common
# Out:
#    Superpower Name  DC Comics
# 17  Super Strength        109
# 25         Stamina         90
# 8           Flight         86
# 30     Super Speed         79
# 5       Durability         71

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %%
from itertools import combinations
powers = list(powers_df.index)
power_combos = list(combinations(powers, 2))

# %%
power_df_transpose = powers_df.T

# %%
combo = power_combos[0]
combo
# Out:
# ('Agility', 'Accelerated Healing')

# %%
len(power_df_transpose[power_df_transpose[combo[0]] & power_df_transpose[combo[1]]])
# Out:
# 101

# %%
power_combo_dict = {}
for combo in power_combos:
    num_occurences = len(power_df_transpose[power_df_transpose[combo[0]] & power_df_transpose[combo[1]]])
    power_combo_dict[combo] = num_occurences
    
power_combos_sorted = {k: v for k, v in sorted(power_combo_dict.items(), key = lambda item: item[1], reverse = True)}

# %%
power_combos_sorted
# Out:
# {('Durability', 'Super Strength'): 227,
#  ('Super Strength', 'Stamina'): 221,
#  ('Super Strength', 'Super Speed'): 219,
#  ('Agility', 'Stamina'): 178,
#  ('Stamina', 'Super Speed'): 171,
#  ('Agility', 'Super Strength'): 168,
#  ('Durability', 'Stamina'): 163,
#  ('Flight', 'Super Strength'): 147,
#  ('Durability', 'Super Speed'): 144,
#  ('Accelerated Healing', 'Super Strength'): 143,
#  ('Agility', 'Super Speed'): 142,
#  ('Stamina', 'Reflexes'): 136,
#  ('Accelerated Healing', 'Stamina'): 127,
#  ('Agility', 'Reflexes'): 125,
#  ('Super Strength', 'Reflexes'): 123,
#  ('Super Speed', 'Reflexes'): 119,
#  ('Accelerated Healing', 'Super Speed'): 117,
#  ('Flight', 'Super Speed'): 117,
#  ('Agility', 'Durability'): 114,
#  ('Super Strength', 'Invulnerability'): 110,
#  ('Accelerated Healing', 'Durability'): 103,
#  ('Agility', 'Accelerated Healing'): 101,
#  ('Durability', 'Reflexes'): 100,
#  ('Super Strength', 'Energy Blasts'): 100,
#  ('Durability', 'Flight'): 96,
#  ('Agility', 'Stealth'): 95,
#  ('Stealth', 'Stamina'): 95,
#  ('Flight', 'Energy Blasts'): 95,
#  ('Flight', 'Stamina'): 92,
#  ('Longevity', 'Super Strength'): 89,
#  ('Marksmanship', 'Stamina'): 88,
#  ('Intelligence', 'Super Strength'): 88,
#  ('Intelligence', 'Stamina'): 86,
#  ('Agility', 'Marksmanship'): 85,
#  ('Longevity', 'Stamina'): 83,
#  ('Accelerated Healing', 'Reflexes'): 82,
#  ('Stamina', 'Invulnerability'): 81,
#  ('Super Speed', 'Invulnerability'): 77,
#  ('Accelerated Healing', 'Flight'): 75,
#  ('Durability', 'Invulnerability'): 75,
#  ('Agility', 'Flight'): 74,
#  ('Agility', 'Intelligence'): 74,
#  ('Weapons Master', 'Stamina'): 74,
#  ('Energy Blasts', 'Super Speed'): 73,
#  ('Durability', 'Longevity'): 72,
#  ('Agility', 'Weapons Master'): 71,
#  ('Durability', 'Intelligence'): 71,
#  ('Super Strength', 'Enhanced Senses'): 71,
#  ('Stealth', 'Weapons Master'): 69,
#  ('Marksmanship', 'Weapons Master'): 69,
#  ('Accelerated Healing', 'Longevity'): 68,
#  ('Stealth', 'Marksmanship'): 67,
#  ('Flight', 'Invulnerability'): 66,
#  ('Durability', 'Energy Blasts'): 65,
#  ('Flight', 'Intelligence'): 65,
#  ('Flight', 'Force Fields'): 65,
#  ('Longevity', 'Super Speed'): 64,
#  ('Super Speed', 'Enhanced Senses'): 64,
#  ('Intelligence', 'Super Speed'): 63,
#  ('Agility', 'Energy Blasts'): 61,
#  ('Accelerated Healing', 'Invulnerability'): 61,
#  ('Stealth', 'Super Strength'): 61,
#  ('Stamina', 'Enhanced Senses'): 61,
#  ('Stealth', 'Intelligence'): 60,
#  ('Stealth', 'Reflexes'): 60,
#  ('Super Strength', 'Enhanced Hearing'): 60,
#  ('Energy Blasts', 'Stamina'): 59,
#  ('Agility', 'Longevity'): 58,
#  ('Agility', 'Enhanced Senses'): 58,
#  ('Energy Blasts', 'Force Fields'): 57,
#  ('Super Strength', 'Jump'): 56,
#  ('Accelerated Healing', 'Energy Blasts'): 55,
#  ('Marksmanship', 'Reflexes'): 55,
#  ('Super Strength', 'Immortality'): 54,
#  ('Stamina', 'Enhanced Hearing'): 54,
#  ('Super Speed', 'Enhanced Hearing'): 54,
#  ('Accelerated Healing', 'Intelligence'): 53,
#  ('Energy Absorption', 'Super Strength'): 53,
#  ('Marksmanship', 'Super Strength'): 53,
#  ('Super Strength', 'Telepathy'): 53,
#  ('Accelerated Healing', 'Enhanced Senses'): 52,
#  ('Durability', 'Stealth'): 52,
#  ('Durability', 'Enhanced Senses'): 52,
#  ('Super Strength', 'Force Fields'): 52,
#  ('Agility', 'Invulnerability'): 51,
#  ('Marksmanship', 'Intelligence'): 51,
#  ('Flight', 'Longevity'): 50,
#  ('Super Strength', 'Shapeshifting'): 50,
#  ('Durability', 'Marksmanship'): 49,
#  ('Stealth', 'Super Speed'): 49,
#  ('Energy Absorption', 'Flight'): 49,
#  ('Flight', 'Reflexes'): 49,
#  ('Longevity', 'Intelligence'): 49,
#  ('Intelligence', 'Reflexes'): 49,
#  ('Marksmanship', 'Super Speed'): 48,
#  ('Weapons Master', 'Intelligence'): 48,
#  ('Longevity', 'Invulnerability'): 48,
#  ('Stamina', 'Jump'): 48,
#  ('Super Speed', 'Force Fields'): 48,
#  ('Durability', 'Jump'): 47,
#  ('Energy Absorption', 'Energy Blasts'): 47,
#  ('Super Strength', 'Natural Weapons'): 47,
#  ('Energy Blasts', 'Invulnerability'): 47,
#  ('Flight', 'Telepathy'): 46,
#  ('Intelligence', 'Invulnerability'): 46,
#  ('Super Speed', 'Jump'): 46,
#  ('Agility', 'Enhanced Hearing'): 45,
#  ('Accelerated Healing', 'Stealth'): 45,
#  ('Telepathy', 'Super Speed'): 45,
#  ('Accelerated Healing', 'Marksmanship'): 44,
#  ('Accelerated Healing', 'Jump'): 44,
#  ('Durability', 'Enhanced Hearing'): 44,
#  ('Energy Absorption', 'Super Speed'): 44,
#  ('Flight', 'Enhanced Senses'): 44,
#  ('Enhanced Senses', 'Reflexes'): 44,
#  ('Longevity', 'Reflexes'): 43,
#  ('Intelligence', 'Energy Blasts'): 43,
#  ('Agility', 'Jump'): 42,
#  ('Weapons Master', 'Reflexes'): 42,
#  ('Super Strength', 'Size Changing'): 42,
#  ('Super Strength', 'Toxin and Disease Resistance'): 42,
#  ('Stamina', 'Toxin and Disease Resistance'): 42,
#  ('Cold Resistance', 'Super Strength'): 41,
#  ('Durability', 'Energy Absorption'): 41,
#  ('Flight', 'Teleportation'): 41,
#  ('Stamina', 'Immortality'): 41,
#  ('Cold Resistance', 'Durability'): 40,
#  ('Energy Absorption', 'Invulnerability'): 40,
#  ('Weapons Master', 'Super Strength'): 40,
#  ('Super Strength', 'Teleportation'): 40,
#  ('Telepathy', 'Stamina'): 40,
#  ('Telepathy', 'Telekinesis'): 40,
#  ('Super Speed', 'Immortality'): 40,
#  ('Immortality', 'Invulnerability'): 40,
#  ('Intelligence', 'Telepathy'): 39,
#  ('Intelligence', 'Force Fields'): 39,
#  ('Telepathy', 'Energy Blasts'): 39,
#  ('Energy Blasts', 'Energy Manipulation'): 39,
#  ('Agility', 'Force Fields'): 38,
#  ('Accelerated Healing', 'Enhanced Hearing'): 38,
#  ('Flight', 'Enhanced Hearing'): 38,
#  ('Flight', 'Energy Manipulation'): 38,
#  ('Super Strength', 'Vision - Telescopic'): 38,
#  ('Stamina', 'Force Fields'): 38,
#  ('Accelerated Healing', 'Immortality'): 37,
#  ('Durability', 'Toxin and Disease Resistance'): 37,
#  ('Flight', 'Immortality'): 37,
#  ('Jump', 'Reflexes'): 37,
#  ('Durability', 'Weapons Master'): 36,
#  ('Energy Absorption', 'Stamina'): 36,
#  ('Longevity', 'Energy Blasts'): 36,
#  ('Super Strength', 'Heat Resistance'): 36,
#  ('Super Speed', 'Shapeshifting'): 36,
#  ('Enhanced Senses', 'Enhanced Hearing'): 36,
#  ('Agility', 'Telepathy'): 35,
#  ('Agility', 'Immortality'): 35,
#  ('Agility', 'Natural Weapons'): 35,
#  ('Accelerated Healing', 'Energy Absorption'): 35,
#  ('Durability', 'Vision - Telescopic'): 35,
#  ('Flight', 'Telekinesis'): 35,
#  ('Marksmanship', 'Energy Blasts'): 35,
#  ('Stamina', 'Shapeshifting'): 35,
#  ('Accelerated Healing', 'Weapons Master'): 34,
#  ('Accelerated Healing', 'Telepathy'): 34,
#  ('Accelerated Healing', 'Teleportation'): 34,
#  ('Accelerated Healing', 'Force Fields'): 34,
#  ('Accelerated Healing', 'Toxin and Disease Resistance'): 34,
#  ('Durability', 'Force Fields'): 34,
#  ('Durability', 'Natural Weapons'): 34,
#  ('Super Strength', 'Molecular Manipulation'): 34,
#  ('Energy Blasts', 'Teleportation'): 34,
#  ('Energy Blasts', 'Telekinesis'): 34,
#  ('Energy Blasts', 'Reflexes'): 34,
#  ('Invulnerability', 'Enhanced Hearing'): 34,
#  ('Agility', 'Shapeshifting'): 33,
#  ('Durability', 'Telepathy'): 33,
#  ('Durability', 'Immortality'): 33,
#  ('Intelligence', 'Enhanced Senses'): 33,
#  ('Super Strength', 'Animal Oriented Powers'): 33,
#  ('Super Strength', 'Telekinesis'): 33,
#  ('Super Strength', 'Self-Sustenance'): 33,
#  ('Super Strength', 'Energy Manipulation'): 33,
#  ('Stamina', 'Weapon-based Powers'): 33,
#  ('Stamina', 'Vision - Telescopic'): 33,
#  ('Super Speed', 'Teleportation'): 33,
#  ('Agility', 'Energy Absorption'): 32,
#  ('Accelerated Healing', 'Shapeshifting'): 32,
#  ('Durability', 'Heat Resistance'): 32,
#  ('Intelligence', 'Enhanced Hearing'): 32,
#  ('Super Strength', 'Wallcrawling'): 32,
#  ('Telepathy', 'Force Fields'): 32,
#  ('Stamina', 'Teleportation'): 32,
#  ('Stamina', 'Natural Weapons'): 32,
#  ('Super Speed', 'Natural Weapons'): 32,
#  ('Reflexes', 'Invulnerability'): 32,
#  ('Reflexes', 'Enhanced Hearing'): 32,
#  ('Flight', 'Marksmanship'): 31,
#  ('Longevity', 'Enhanced Hearing'): 31,
#  ('Super Strength', 'Energy Beams'): 31,
#  ('Agility', 'Teleportation'): 30,
#  ('Cold Resistance', 'Stamina'): 30,
#  ('Flight', 'Molecular Manipulation'): 30,
#  ('Weapons Master', 'Longevity'): 30,
#  ('Weapons Master', 'Super Speed'): 30,
#  ('Longevity', 'Enhanced Senses'): 30,
#  ('Longevity', 'Immortality'): 30,
#  ('Super Strength', 'Weapon-based Powers'): 30,
#  ('Super Strength', 'Vision - Night'): 30,
#  ('Energy Blasts', 'Energy Beams'): 30,
#  ('Super Speed', 'Telekinesis'): 30,
#  ('Super Speed', 'Molecular Manipulation'): 30,
#  ('Super Speed', 'Vision - Telescopic'): 30,
#  ('Enhanced Senses', 'Invulnerability'): 30,
#  ('Telekinesis', 'Force Fields'): 30,
#  ('Agility', 'Weapon-based Powers'): 29,
#  ('Agility', 'Toxin and Disease Resistance'): 29,
#  ('Agility', 'Wallcrawling'): 29,
#  ('Durability', 'Shapeshifting'): 29,
#  ('Flight', 'Energy Constructs'): 29,
#  ('Super Strength', 'Magic'): 29,
#  ('Size Changing', 'Invulnerability'): 29,
#  ('Super Speed', 'Toxin and Disease Resistance'): 29,
#  ('Reflexes', 'Toxin and Disease Resistance'): 29,
#  ('Enhanced Hearing', 'Vision - Telescopic'): 29,
#  ('Accelerated Healing', 'Natural Weapons'): 28,
#  ('Cold Resistance', 'Heat Resistance'): 28,
#  ('Stealth', 'Longevity'): 28,
#  ('Energy Absorption', 'Energy Manipulation'): 28,
#  ('Flight', 'Shapeshifting'): 28,
#  ('Flight', 'Vision - Telescopic'): 28,
#  ('Marksmanship', 'Longevity'): 28,
#  ('Telepathy', 'Teleportation'): 28,
#  ('Energy Blasts', 'Immortality'): 28,
#  ('Stamina', 'Vision - Night'): 28,
#  ('Reflexes', 'Natural Weapons'): 28,
#  ('Invulnerability', 'Force Fields'): 28,
#  ('Accelerated Healing', 'Vision - Telescopic'): 27,
#  ('Durability', 'Weapon-based Powers'): 27,
#  ('Durability', 'Vision - Night'): 27,
#  ('Flight', 'Size Changing'): 27,
#  ('Flight', 'Energy Beams'): 27,
#  ('Intelligence', 'Immortality'): 27,
#  ('Telepathy', 'Reflexes'): 27,
#  ('Stamina', 'Enhanced Smell'): 27,
#  ('Super Speed', 'Self-Sustenance'): 27,
#  ('Super Speed', 'Wallcrawling'): 27,
#  ('Teleportation', 'Invulnerability'): 27,
#  ('Agility', 'Danger Sense'): 26,
#  ('Agility', 'Animal Oriented Powers'): 26,
#  ('Stealth', 'Enhanced Hearing'): 26,
#  ('Longevity', 'Teleportation'): 26,
#  ('Intelligence', 'Size Changing'): 26,
#  ('Intelligence', 'Telekinesis'): 26,
#  ('Super Strength', 'Natural Armor'): 26,
#  ('Super Strength', 'Enhanced Smell'): 26,
#  ('Energy Blasts', 'Energy Constructs'): 26,
#  ('Energy Blasts', 'Molecular Manipulation'): 26,
#  ('Stamina', 'Wallcrawling'): 26,
#  ('Super Speed', 'Weapon-based Powers'): 26,
#  ('Enhanced Senses', 'Jump'): 26,
#  ('Reflexes', 'Vision - Night'): 26,
#  ('Enhanced Hearing', 'Enhanced Smell'): 26,
#  ('Agility', 'Cold Resistance'): 25,
#  ('Agility', 'Enhanced Smell'): 25,
#  ('Accelerated Healing', 'Telekinesis'): 25,
#  ('Cold Resistance', 'Super Speed'): 25,
#  ('Durability', 'Energy Beams'): 25,
#  ('Durability', 'Self-Sustenance'): 25,
#  ('Stealth', 'Jump'): 25,
#  ('Flight', 'Phasing'): 25,
#  ('Danger Sense', 'Super Strength'): 25,
#  ('Danger Sense', 'Super Speed'): 25,
#  ('Longevity', 'Toxin and Disease Resistance'): 25,
#  ('Telepathy', 'Invulnerability'): 25,
#  ('Telepathy', 'Psionic Powers'): 25,
#  ('Telepathy', 'Illusions'): 25,
#  ('Size Changing', 'Shapeshifting'): 25,
#  ('Stamina', 'Magic'): 25,
#  ('Stamina', 'Heat Resistance'): 25,
#  ('Super Speed', 'Animal Oriented Powers'): 25,
#  ('Super Speed', 'Energy Manipulation'): 25,
#  ('Agility', 'Telekinesis'): 24,
#  ('Agility', 'Energy Manipulation'): 24,
#  ('Agility', 'Vision - Telescopic'): 24,
#  ('Agility', 'Vision - Night'): 24,
#  ('Accelerated Healing', 'Magic'): 24,
#  ('Durability', 'Size Changing'): 24,
#  ('Durability', 'Energy Manipulation'): 24,
#  ('Stealth', 'Flight'): 24,
#  ('Longevity', 'Telepathy'): 24,
#  ('Intelligence', 'Teleportation'): 24,
#  ('Stamina', 'Animal Oriented Powers'): 24,
#  ('Stamina', 'Energy Beams'): 24,
#  ('Stamina', 'Self-Sustenance'): 24,
#  ('Super Speed', 'Energy Constructs'): 24,
#  ('Super Speed', 'Vision - Night'): 24,
#  ('Teleportation', 'Magic'): 24,
#  ('Teleportation', 'Immortality'): 24,
#  ('Teleportation', 'Force Fields'): 24,
#  ('Reflexes', 'Wallcrawling'): 24,
#  ('Accelerated Healing', 'Cold Resistance'): 23,
#  ('Cold Resistance', 'Reflexes'): 23,
#  ('Durability', 'Teleportation'): 23,
#  ('Durability', 'Natural Armor'): 23,
#  ('Stealth', 'Telepathy'): 23,
#  ('Energy Absorption', 'Longevity'): 23,
#  ('Energy Absorption', 'Force Fields'): 23,
#  ('Flight', 'Self-Sustenance'): 23,
#  ('Flight', 'Time Travel'): 23,
#  ('Flight', 'Vision - X-Ray'): 23,
#  ('Marksmanship', 'Force Fields'): 23,
#  ('Longevity', 'Force Fields'): 23,
#  ('Super Strength', 'Energy Constructs'): 23,
#  ('Super Strength', 'Psionic Powers'): 23,
#  ('Super Strength', 'Vision - X-Ray'): 23,
#  ('Super Strength', 'Vision - Thermal'): 23,
#  ('Telepathy', 'Astral Projection'): 23,
#  ('Size Changing', 'Super Speed'): 23,
#  ('Stamina', 'Natural Armor'): 23,
#  ('Teleportation', 'Telekinesis'): 23,
#  ('Jump', 'Enhanced Hearing'): 23,
#  ('Shapeshifting', 'Invulnerability'): 23,
#  ('Invulnerability', 'Energy Manipulation'): 23,
#  ('Force Fields', 'Energy Manipulation'): 23,
#  ('Agility', 'Heat Resistance'): 22,
#  ('Accelerated Healing', 'Danger Sense'): 22,
#  ('Accelerated Healing', 'Wallcrawling'): 22,
#  ('Danger Sense', 'Stamina'): 22,
#  ('Marksmanship', 'Weapon-based Powers'): 22,
#  ('Marksmanship', 'Jump'): 22,
#  ('Weapons Master', 'Energy Blasts'): 22,
#  ('Super Strength', 'Enhanced Sight'): 22,
#  ('Super Strength', 'Power Suit'): 22,
#  ('Energy Blasts', 'Size Changing'): 22,
#  ('Stamina', 'Telekinesis'): 22,
#  ('Super Speed', 'Energy Beams'): 22,
#  ('Super Speed', 'Enhanced Smell'): 22,
#  ('Weapon-based Powers', 'Reflexes'): 22,
#  ('Telekinesis', 'Astral Projection'): 22,
#  ('Telekinesis', 'Illusions'): 22,
#  ('Invulnerability', 'Self-Sustenance'): 22,
#  ('Invulnerability', 'Heat Resistance'): 22,
#  ('Energy Constructs', 'Force Fields'): 22,
#  ('Enhanced Hearing', 'Vision - Night'): 22,
#  ('Agility', 'Psionic Powers'): 21,
#  ('Dimensional Awareness', 'Teleportation'): 21,
#  ('Durability', 'Molecular Manipulation'): 21,
#  ('Durability', 'Wallcrawling'): 21,
#  ('Stealth', 'Enhanced Senses'): 21,
#  ('Energy Absorption', 'Intelligence'): 21,
#  ('Energy Absorption', 'Immortality'): 21,
#  ('Flight', 'Fire Control'): 21,
#  ('Danger Sense', 'Reflexes'): 21,
#  ('Weapons Master', 'Enhanced Senses'): 21,
#  ('Super Strength', 'Super Breath'): 21,
#  ('Super Strength', 'Vision - Infrared'): 21,
#  ('Energy Blasts', 'Enhanced Senses'): 21,
#  ('Energy Blasts', 'Enhanced Hearing'): 21,
#  ('Size Changing', 'Stamina'): 21,
#  ('Stamina', 'Enhanced Sight'): 21,
#  ('Super Speed', 'Magic'): 21,
#  ('Jump', 'Natural Weapons'): 21,
#  ('Reflexes', 'Vision - Telescopic'): 21,
#  ('Vision - Telescopic', 'Vision - Night'): 21,
#  ('Agility', 'Peak Human Condition'): 20,
#  ('Accelerated Healing', 'Energy Constructs'): 20,
#  ('Accelerated Healing', 'Molecular Manipulation'): 20,
#  ('Accelerated Healing', 'Enhanced Smell'): 20,
#  ('Cold Resistance', 'Longevity'): 20,
#  ('Cold Resistance', 'Invulnerability'): 20,
#  ('Durability', 'Telekinesis'): 20,
#  ('Stealth', 'Invulnerability'): 20,
#  ('Stealth', 'Natural Weapons'): 20,
#  ('Flight', 'Magic'): 20,
#  ('Flight', 'Psionic Powers'): 20,
#  ('Marksmanship', 'Peak Human Condition'): 20,
#  ('Marksmanship', 'Enhanced Hearing'): 20,
#  ('Weapons Master', 'Weapon-based Powers'): 20,
#  ('Animal Attributes', 'Super Strength'): 20,
#  ('Super Strength', 'Technopath/Cyberpath'): 20,
#  ('Super Strength', 'Time Travel'): 20,
#  ('Super Strength', 'Illusions'): 20,
#  ('Energy Blasts', 'Psionic Powers'): 20,
#  ('Energy Blasts', 'Time Travel'): 20,
#  ('Stamina', 'Enhanced Memory'): 20,
#  ('Super Speed', 'Heat Resistance'): 20,
#  ('Super Speed', 'Time Travel'): 20,
#  ('Super Speed', 'Super Breath'): 20,
#  ('Enhanced Senses', 'Enhanced Smell'): 20,
#  ('Enhanced Senses', 'Vision - Telescopic'): 20,
#  ('Telekinesis', 'Invulnerability'): 20,
#  ('Telekinesis', 'Psionic Powers'): 20,
#  ('Energy Beams', 'Force Fields'): 20,
#  ('Immortality', 'Energy Manipulation'): 20,
#  ('Astral Projection', 'Illusions'): 20,
#  ('Invulnerability', 'Vision - Telescopic'): 20,
#  ('Invulnerability', 'Toxin and Disease Resistance'): 20,
#  ('Invulnerability', 'Vision - X-Ray'): 20,
#  ('Agility', 'Size Changing'): 19,
#  ('Accelerated Healing', 'Animal Oriented Powers'): 19,
#  ('Accelerated Healing', 'Self-Sustenance'): 19,
#  ('Accelerated Healing', 'Energy Manipulation'): 19,
#  ('Accelerated Healing', 'Heat Resistance'): 19,
#  ('Durability', 'Danger Sense'): 19,
#  ('Durability', 'Animal Oriented Powers'): 19,
#  ('Durability', 'Enhanced Smell'): 19,
#  ('Durability', 'Vision - Infrared'): 19,
#  ('Durability', 'Vision - Thermal'): 19,
#  ('Energy Absorption', 'Energy Beams'): 19,
#  ('Flight', 'Illusions'): 19,
#  ('Flight', 'Super Breath'): 19,
#  ('Underwater breathing', 'Super Strength'): 19,
#  ('Marksmanship', 'Enhanced Senses'): 19,
#  ('Animal Attributes', 'Animal Oriented Powers'): 19,
#  ('Longevity', 'Magic'): 19,
#  ('Longevity', 'Shapeshifting'): 19,
#  ('Longevity', 'Enhanced Smell'): 19,
#  ('Intelligence', 'Energy Beams'): 19,
#  ('Telepathy', 'Immortality'): 19,
#  ('Energy Blasts', 'Magic'): 19,
#  ('Energy Blasts', 'Shapeshifting'): 19,
#  ('Energy Blasts', 'Fire Control'): 19,
#  ('Stamina', 'Energy Manipulation'): 19,
#  ('Stamina', 'Vision - Infrared'): 19,
#  ('Stamina', 'Vision - Thermal'): 19,
#  ('Super Speed', 'Phasing'): 19,
#  ('Super Speed', 'Psionic Powers'): 19,
#  ('Super Speed', 'Vision - X-Ray'): 19,
#  ('Animal Oriented Powers', 'Reflexes'): 19,
#  ('Teleportation', 'Energy Manipulation'): 19,
#  ('Magic', 'Invulnerability'): 19,
#  ('Jump', 'Invulnerability'): 19,
#  ('Immortality', 'Force Fields'): 19,
#  ('Immortality', 'Molecular Manipulation'): 19,
#  ('Reflexes', 'Force Fields'): 19,
#  ('Invulnerability', 'Molecular Manipulation'): 19,
#  ('Invulnerability', 'Super Breath'): 19,
#  ('Force Fields', 'Psionic Powers'): 19,
#  ('Natural Weapons', 'Wallcrawling'): 19,
#  ('Agility', 'Natural Armor'): 18,
#  ('Agility', 'Enhanced Sight'): 18,
#  ('Agility', 'Molecular Manipulation'): 18,
#  ('Agility', 'Illusions'): 18,
#  ('Accelerated Healing', 'Size Changing'): 18,
#  ('Accelerated Healing', 'Illusions'): 18,
#  ('Accelerated Healing', 'Vision - Night'): 18,
#  ('Dimensional Awareness', 'Immortality'): 18,
#  ('Durability', 'Magic'): 18,
#  ('Durability', 'Enhanced Memory'): 18,
#  ('Durability', 'Power Suit'): 18,
#  ('Durability', 'Vision - X-Ray'): 18,
#  ('Stealth', 'Energy Blasts'): 18,
#  ('Stealth', 'Force Fields'): 18,
#  ('Flight', 'Astral Projection'): 18,
#  ('Flight', 'Power Suit'): 18,
#  ('Flight', 'Invisibility'): 18,
#  ('Weapons Master', 'Peak Human Condition'): 18,
#  ('Longevity', 'Jump'): 18,
#  ('Intelligence', 'Magic'): 18,
#  ('Intelligence', 'Jump'): 18,
#  ('Intelligence', 'Energy Manipulation'): 18,
#  ('Super Strength', 'Fire Control'): 18,
#  ('Super Strength', 'Enhanced Memory'): 18,
#  ('Super Strength', 'Heat Generation'): 18,
#  ('Super Strength', 'Regeneration'): 18,
#  ('Super Strength', 'Telepathy Resistance'): 18,
#  ('Super Strength', 'Vision - Microscopic'): 18,
#  ('Super Strength', 'Vision - Heat'): 18,
#  ('Energy Blasts', 'Heat Resistance'): 18,
#  ('Energy Blasts', 'Illusions'): 18,
#  ('Size Changing', 'Immortality'): 18,
#  ('Stamina', 'Peak Human Condition'): 18,
#  ('Stamina', 'Energy Constructs'): 18,
#  ('Stamina', 'Super Breath'): 18,
#  ('Super Speed', 'Natural Armor'): 18,
#  ('Super Speed', 'Vision - Thermal'): 18,
#  ('Teleportation', 'Molecular Manipulation'): 18,
#  ('Teleportation', 'Time Travel'): 18,
#  ('Enhanced Senses', 'Vision - Night'): 18,
#  ('Shapeshifting', 'Reflexes'): 18,
#  ('Immortality', 'Reflexes'): 18,
#  ('Force Fields', 'Illusions'): 18,
#  ('Natural Armor', 'Natural Weapons'): 18,
#  ('Agility', 'Energy Beams'): 17,
#  ('Agility', 'Magic'): 17,
#  ('Agility', 'Energy Constructs'): 17,
#  ('Agility', 'Telepathy Resistance'): 17,
#  ('Accelerated Healing', 'Psionic Powers'): 17,
#  ('Accelerated Healing', 'Time Travel'): 17,
#  ('Durability', 'Underwater breathing'): 17,
#  ('Durability', 'Enhanced Sight'): 17,
#  ('Durability', 'Regeneration'): 17,
#  ('Durability', 'Super Breath'): 17,
#  ('Stealth', 'Shapeshifting'): 17,
#  ('Stealth', 'Immortality'): 17,
#  ('Stealth', 'Toxin and Disease Resistance'): 17,
#  ('Stealth', 'Vision - Night'): 17,
#  ('Energy Absorption', 'Enhanced Senses'): 17,
#  ('Energy Absorption', 'Enhanced Hearing'): 17,
#  ('Flight', 'Levitation'): 17,
#  ('Flight', 'Heat Resistance'): 17,
#  ('Flight', 'Toxin and Disease Resistance'): 17,
#  ('Flight', 'Vision - Heat'): 17,
#  ('Marksmanship', 'Telepathy'): 17,
#  ('Marksmanship', 'Invulnerability'): 17,
#  ('Weapons Master', 'Enhanced Hearing'): 17,
#  ('Intelligence', 'Molecular Manipulation'): 17,
#  ('Intelligence', 'Illusions'): 17,
#  ('Super Strength', 'Dimensional Travel'): 17,
#  ('Super Strength', 'Camouflage'): 17,
#  ('Super Strength', 'Phasing'): 17,
#  ('Super Strength', 'Omnilingualism'): 17,
#  ('Telepathy', 'Size Changing'): 17,
#  ('Telepathy', 'Shapeshifting'): 17,
#  ('Telepathy', 'Enhanced Hearing'): 17,
#  ('Telepathy', 'Molecular Manipulation'): 17,
#  ('Energy Blasts', 'Levitation'): 17,
#  ('Stamina', 'Molecular Manipulation'): 17,
#  ('Stamina', 'Regeneration'): 17,
#  ('Stamina', 'Vision - Microscopic'): 17,
#  ('Super Speed', 'Dimensional Travel'): 17,
#  ('Super Speed', 'Enhanced Memory'): 17,
#  ('Super Speed', 'Enhanced Sight'): 17,
#  ('Super Speed', 'Illusions'): 17,
#  ('Super Speed', 'Vision - Microscopic'): 17,
#  ('Super Speed', 'Vision - Heat'): 17,
#  ('Teleportation', 'Reflexes'): 17,
#  ('Shapeshifting', 'Natural Weapons'): 17,
#  ('Enhanced Memory', 'Enhanced Hearing'): 17,
#  ('Reflexes', 'Enhanced Smell'): 17,
#  ('Invulnerability', 'Vision - Heat'): 17,
#  ('Force Fields', 'Levitation'): 17,
#  ('Force Fields', 'Time Travel'): 17,
#  ('Enhanced Hearing', 'Enhanced Sight'): 17,
#  ('Enhanced Hearing', 'Vision - Microscopic'): 17,
#  ('Enhanced Hearing', 'Super Breath'): 17,
#  ('Enhanced Hearing', 'Vision - X-Ray'): 17,
#  ('Vision - Telescopic', 'Vision - Microscopic'): 17,
#  ('Vision - Telescopic', 'Vision - X-Ray'): 17,
#  ('Agility', 'Levitation'): 16,
#  ('Accelerated Healing', 'Super Breath'): 16,
#  ('Dimensional Awareness', 'Flight'): 16,
#  ('Cold Resistance', 'Enhanced Senses'): 16,
#  ('Durability', 'Vision - Microscopic'): 16,
#  ('Stealth', 'Danger Sense'): 16,
#  ('Stealth', 'Peak Human Condition'): 16,
#  ('Energy Absorption', 'Vision - Telescopic'): 16,
#  ('Flight', 'Intangibility'): 16,
#  ('Flight', 'Vision - Microscopic'): 16,
#  ('Danger Sense', 'Jump'): 16,
#  ('Marksmanship', 'Toxin and Disease Resistance'): 16,
#  ('Animal Attributes', 'Stamina'): 16,
#  ('Animal Attributes', 'Super Speed'): 16,
#  ('Longevity', 'Telekinesis'): 16,
#  ('Longevity', 'Self-Sustenance'): 16,
#  ('Intelligence', 'Shapeshifting'): 16,
#  ('Intelligence', 'Hypnokinesis'): 16,
#  ('Intelligence', 'Omnilingualism'): 16,
#  ('Super Strength', 'Precognition'): 16,
#  ('Stamina', 'Psionic Powers'): 16,
#  ('Stamina', 'Illusions'): 16,
#  ('Stamina', 'Vision - X-Ray'): 16,
#  ('Super Speed', 'Precognition'): 16,
#  ('Teleportation', 'Phasing'): 16,
#  ('Teleportation', 'Energy Constructs'): 16,
#  ('Teleportation', 'Illusions'): 16,
#  ('Enhanced Senses', 'Toxin and Disease Resistance'): 16,
#  ('Telekinesis', 'Molecular Manipulation'): 16,
#  ('Magic', 'Immortality'): 16,
#  ('Jump', 'Wallcrawling'): 16,
#  ('Immortality', 'Toxin and Disease Resistance'): 16,
#  ('Astral Projection', 'Psionic Powers'): 16,
#  ('Enhanced Memory', 'Reflexes'): 16,
#  ('Enhanced Memory', 'Vision - Telescopic'): 16,
#  ('Invulnerability', 'Time Travel'): 16,
#  ('Force Fields', 'Invisibility'): 16,
#  ('Psionic Powers', 'Illusions'): 16,
#  ('Molecular Manipulation', 'Energy Manipulation'): 16,
#  ('Time Travel', 'Time Manipulation'): 16,
#  ('Vision - Telescopic', 'Vision - Infrared'): 16,
#  ('Agility', 'Animal Attributes'): 15,
#  ('Agility', 'Astral Projection'): 15,
#  ('Agility', 'Enhanced Memory'): 15,
#  ('Agility', 'Sub-Mariner'): 15,
#  ('Accelerated Healing', 'Astral Projection'): 15,
#  ('Accelerated Healing', 'Fire Control'): 15,
#  ('Accelerated Healing', 'Hypnokinesis'): 15,
#  ('Accelerated Healing', 'Enhanced Sight'): 15,
#  ('Accelerated Healing', 'Regeneration'): 15,
#  ('Dimensional Awareness', 'Super Strength'): 15,
#  ('Cold Resistance', 'Enhanced Hearing'): 15,
#  ('Durability', 'Camouflage'): 15,
#  ('Durability', 'Illusions'): 15,
#  ('Stealth', 'Enhanced Smell'): 15,
#  ('Energy Absorption', 'Telepathy'): 15,
#  ('Energy Absorption', 'Reflexes'): 15,
#  ('Energy Absorption', 'Molecular Manipulation'): 15,
#  ('Flight', 'Weapons Master'): 15,
#  ('Flight', 'Animal Oriented Powers'): 15,
#  ('Flight', 'Weapon-based Powers'): 15,
#  ('Danger Sense', 'Wallcrawling'): 15,
#  ('Marksmanship', 'Energy Beams'): 15,
#  ('Longevity', 'Enhanced Sight'): 15,
#  ('Longevity', 'Heat Resistance'): 15,
#  ('Intelligence', 'Energy Constructs'): 15,
#  ('Intelligence', 'Time Travel'): 15,
#  ('Intelligence', 'Toxin and Disease Resistance'): 15,
#  ('Super Strength', 'Astral Projection'): 15,
#  ('Super Strength', 'Fire Resistance'): 15,
#  ('Super Strength', 'Time Manipulation'): 15,
#  ('Telepathy', 'Mind Control'): 15,
#  ('Telepathy', 'Energy Manipulation'): 15,
#  ('Energy Blasts', 'Weapon-based Powers'): 15,
#  ('Energy Blasts', 'Phasing'): 15,
#  ('Energy Blasts', 'Self-Sustenance'): 15,
#  ('Energy Blasts', 'Heat Generation'): 15,
#  ('Stamina', 'Camouflage'): 15,
#  ('Stamina', 'Technopath/Cyberpath'): 15,
#  ('Stamina', 'Telepathy Resistance'): 15,
#  ('Stamina', 'Sub-Mariner'): 15,
#  ('Stamina', 'Vision - Heat'): 15,
#  ('Super Speed', 'Astral Projection'): 15,
#  ('Super Speed', 'Invisibility'): 15,
#  ('Super Speed', 'Vision - Infrared'): 15,
#  ('Animal Oriented Powers', 'Natural Weapons'): 15,
#  ('Teleportation', 'Shapeshifting'): 15,
#  ('Teleportation', 'Astral Projection'): 15,
#  ('Enhanced Senses', 'Force Fields'): 15,
#  ('Enhanced Senses', 'Natural Weapons'): 15,
#  ('Telekinesis', 'Mind Control'): 15,
#  ('Reflexes', 'Heat Resistance'): 15,
#  ('Invulnerability', 'Vision - Microscopic'): 15,
#  ('Force Fields', 'Molecular Manipulation'): 15,
#  ('Vision - Telescopic', 'Vision - Thermal'): 15,
#  ('Agility', 'Precognition'): 14,
#  ('Agility', 'Heat Generation'): 14,
#  ('Agility', 'Vision - Infrared'): 14,
#  ('Agility', 'Vision - Thermal'): 14,
#  ('Accelerated Healing', 'Dimensional Awareness'): 14,
#  ('Accelerated Healing', 'Weapon-based Powers'): 14,
#  ('Accelerated Healing', 'Precognition'): 14,
#  ('Accelerated Healing', 'Natural Armor'): 14,
#  ('Accelerated Healing', 'Vision - Thermal'): 14,
#  ('Dimensional Awareness', 'Intelligence'): 14,
#  ('Dimensional Awareness', 'Energy Blasts'): 14,
#  ('Dimensional Awareness', 'Invulnerability'): 14,
#  ('Cold Resistance', 'Intelligence'): 14,
#  ('Durability', 'Animal Attributes'): 14,
#  ('Durability', 'Psionic Powers'): 14,
#  ('Durability', 'Fire Resistance'): 14,
#  ('Stealth', 'Weapon-based Powers'): 14,
#  ('Stealth', 'Illusions'): 14,
#  ('Energy Absorption', 'Marksmanship'): 14,
#  ('Energy Absorption', 'Telekinesis'): 14,
#  ('Energy Absorption', 'Energy Constructs'): 14,
#  ('Energy Absorption', 'Vision - X-Ray'): 14,
#  ('Flight', 'Jump'): 14,
#  ('Flight', 'Dimensional Travel'): 14,
#  ('Flight', 'Heat Generation'): 14,
#  ('Flight', 'Time Manipulation'): 14,
#  ('Danger Sense', 'Marksmanship'): 14,
#  ('Danger Sense', 'Natural Weapons'): 14,
#  ('Underwater breathing', 'Stamina'): 14,
#  ('Underwater breathing', 'Super Speed'): 14,
#  ('Marksmanship', 'Vision - Night'): 14,
#  ('Weapons Master', 'Jump'): 14,
#  ('Weapons Master', 'Invulnerability'): 14,
#  ('Weapons Master', 'Force Fields'): 14,
#  ('Animal Attributes', 'Natural Weapons'): 14,
#  ('Longevity', 'Energy Constructs'): 14,
#  ('Longevity', 'Vision - Telescopic'): 14,
#  ('Intelligence', 'Astral Projection'): 14,
#  ('Intelligence', 'Psionic Powers'): 14,
#  ('Intelligence', 'Precognition'): 14,
#  ('Intelligence', 'Telepathy Resistance'): 14,
#  ('Super Strength', 'Substance Secretion'): 14,
#  ('Super Strength', 'Hypnokinesis'): 14,
#  ('Super Strength', 'Invisibility'): 14,
#  ('Super Strength', 'Sub-Mariner'): 14,
#  ('Telepathy', 'Enhanced Senses'): 14,
#  ('Telepathy', 'Precognition'): 14,
#  ('Telepathy', 'Telepathy Resistance'): 14,
#  ('Energy Blasts', 'Astral Projection'): 14,
#  ('Energy Blasts', 'Precognition'): 14,
#  ('Energy Blasts', 'Light Control'): 14,
#  ('Energy Blasts', 'Vision - Telescopic'): 14,
#  ('Size Changing', 'Teleportation'): 14,
#  ('Stamina', 'Fire Control'): 14,
#  ('Stamina', 'Heat Generation'): 14,
#  ('Super Speed', 'Hypnokinesis'): 14,
#  ('Super Speed', 'Power Suit'): 14,
#  ('Super Speed', 'Time Manipulation'): 14,
#  ('Teleportation', 'Dimensional Travel'): 14,
#  ('Enhanced Senses', 'Heat Resistance'): 14,
#  ('Enhanced Senses', 'Vision - Microscopic'): 14,
#  ('Enhanced Senses', 'Vision - X-Ray'): 14,
#  ('Enhanced Senses', 'Vision - Thermal'): 14,
#  ('Energy Beams', 'Invulnerability'): 14,
#  ('Jump', 'Vision - Telescopic'): 14,
#  ('Shapeshifting', 'Immortality'): 14,
#  ('Phasing', 'Invulnerability'): 14,
#  ('Phasing', 'Time Travel'): 14,
#  ('Astral Projection', 'Force Fields'): 14,
#  ('Energy Constructs', 'Energy Manipulation'): 14,
#  ('Enhanced Hearing', 'Vision - Heat'): 14,
#  ('Enhanced Hearing', 'Vision - Thermal'): 14,
#  ('Vision - Microscopic', 'Vision - X-Ray'): 14,
#  ('Vision - Night', 'Vision - Thermal'): 14,
#  ('Vision - Heat', 'Vision - X-Ray'): 14,
#  ('Agility', 'Camouflage'): 13,
#  ('Agility', 'Fire Control'): 13,
#  ('Agility', 'Time Travel'): 13,
#  ('Agility', 'Super Breath'): 13,
#  ('Accelerated Healing', 'Dimensional Travel'): 13,
#  ('Accelerated Healing', 'Phasing'): 13,
#  ('Accelerated Healing', 'Enhanced Memory'): 13,
#  ('Accelerated Healing', 'Vision - Infrared'): 13,
#  ('Accelerated Healing', 'Vision - X-Ray'): 13,
#  ('Dimensional Awareness', 'Super Speed'): 13,
#  ('Cold Resistance', 'Stealth'): 13,
#  ('Durability', 'Energy Constructs'): 13,
#  ('Durability', 'Technopath/Cyberpath'): 13,
#  ('Durability', 'Telepathy Resistance'): 13,
#  ('Durability', 'Vision - Heat'): 13,
#  ('Stealth', 'Teleportation'): 13,
#  ('Stealth', 'Telekinesis'): 13,
#  ('Stealth', 'Wallcrawling'): 13,
#  ('Energy Absorption', 'Jump'): 13,
#  ('Energy Absorption', 'Time Travel'): 13,
#  ('Energy Absorption', 'Super Breath'): 13,
#  ('Flight', 'Vision - Thermal'): 13,
#  ('Flight', 'Reality Warping'): 13,
#  ('Marksmanship', 'Immortality'): 13,
#  ('Marksmanship', 'Energy Constructs'): 13,
#  ('Marksmanship', 'Enhanced Smell'): 13,
#  ('Marksmanship', 'Vision - Telescopic'): 13,
#  ('Weapons Master', 'Telepathy'): 13,
#  ('Animal Attributes', 'Reflexes'): 13,
#  ('Longevity', 'Size Changing'): 13,
#  ('Longevity', 'Time Travel'): 13,
#  ('Intelligence', 'Weapon-based Powers'): 13,
#  ('Intelligence', 'Phasing'): 13,
#  ('Intelligence', 'Self-Sustenance'): 13,
#  ('Intelligence', 'Power Suit'): 13,
#  ('Intelligence', 'Levitation'): 13,
#  ('Intelligence', 'Vision - Telescopic'): 13,
#  ('Intelligence', 'Time Manipulation'): 13,
#  ('Intelligence', 'Vision - Infrared'): 13,
#  ('Intelligence', 'Reality Warping'): 13,
#  ('Super Strength', 'Duplication'): 13,
#  ('Super Strength', 'Density Control'): 13,
#  ('Super Strength', 'Mind Control'): 13,
#  ('Super Strength', 'Web Creation'): 13,
#  ('Telepathy', 'Magic'): 13,
#  ('Energy Blasts', 'Power Suit'): 13,
#  ('Energy Blasts', 'Invisibility'): 13,
#  ('Size Changing', 'Force Fields'): 13,
#  ('Stamina', 'Power Suit'): 13,
#  ('Stamina', 'Web Creation'): 13,
#  ('Super Speed', 'Fire Control'): 13,
#  ('Super Speed', 'Technopath/Cyberpath'): 13,
#  ('Teleportation', 'Time Manipulation'): 13,
#  ('Teleportation', 'Reality Warping'): 13,
#  ('Enhanced Senses', 'Shapeshifting'): 13,
#  ('Enhanced Senses', 'Enhanced Memory'): 13,
#  ('Telekinesis', 'Immortality'): 13,
#  ('Telekinesis', 'Reflexes'): 13,
#  ('Jump', 'Natural Armor'): 13,
#  ('Jump', 'Super Breath'): 13,
#  ('Shapeshifting', 'Force Fields'): 13,
#  ('Immortality', 'Enhanced Hearing'): 13,
#  ('Reflexes', 'Natural Armor'): 13,
#  ('Reflexes', 'Vision - Infrared'): 13,
#  ('Invulnerability', 'Energy Constructs'): 13,
#  ('Invulnerability', 'Enhanced Sight'): 13,
#  ('Invulnerability', 'Vision - Infrared'): 13,
#  ('Force Fields', 'Enhanced Hearing'): 13,
#  ('Enhanced Hearing', 'Natural Weapons'): 13,
#  ('Enhanced Hearing', 'Vision - Infrared'): 13,
#  ('Enhanced Sight', 'Enhanced Smell'): 13,
#  ('Vision - Telescopic', 'Super Breath'): 13,
#  ('Vision - Microscopic', 'Super Breath'): 13,
#  ('Super Breath', 'Vision - Heat'): 13,
#  ('Super Breath', 'Vision - X-Ray'): 13,
#  ('Wallcrawling', 'Web Creation'): 13,
#  ('Agility', 'Self-Sustenance'): 12,
#  ('Agility', 'Hypnokinesis'): 12,
#  ('Accelerated Healing', 'Energy Beams'): 12,
#  ('Accelerated Healing', 'Camouflage'): 12,
#  ('Accelerated Healing', 'Time Manipulation'): 12,
#  ('Accelerated Healing', 'Vision - Microscopic'): 12,
#  ('Accelerated Healing', 'Vision - Heat'): 12,
#  ('Accelerated Healing', 'Web Creation'): 12,
#  ('Dimensional Awareness', 'Longevity'): 12,
#  ('Dimensional Awareness', 'Telepathy'): 12,
#  ('Dimensional Awareness', 'Telekinesis'): 12,
#  ('Dimensional Awareness', 'Astral Projection'): 12,
#  ('Dimensional Awareness', 'Force Fields'): 12,
#  ('Cold Resistance', 'Vision - Night'): 12,
#  ('Durability', 'Time Travel'): 12,
#  ('Durability', 'Sub-Mariner'): 12,
#  ('Durability', 'Web Creation'): 12,
#  ('Stealth', 'Size Changing'): 12,
#  ('Stealth', 'Animal Oriented Powers'): 12,
#  ('Stealth', 'Natural Armor'): 12,
#  ('Stealth', 'Vision - Telescopic'): 12,
#  ('Energy Absorption', 'Size Changing'): 12,
#  ('Energy Absorption', 'Teleportation'): 12,
#  ('Energy Absorption', 'Phasing'): 12,
#  ('Energy Absorption', 'Self-Sustenance'): 12,
#  ('Flight', 'Electrokinesis'): 12,
#  ('Flight', 'Technopath/Cyberpath'): 12,
#  ('Flight', 'Precognition'): 12,
#  ('Flight', 'Hypnokinesis'): 12,
#  ('Flight', 'Gravity Control'): 12,
#  ('Flight', 'Vision - Infrared'): 12,
#  ('Marksmanship', 'Teleportation'): 12,
#  ('Weapons Master', 'Power Suit'): 12,
#  ('Weapons Master', 'Enhanced Smell'): 12,
#  ('Weapons Master', 'Toxin and Disease Resistance'): 12,
#  ('Longevity', 'Duplication'): 12,
#  ('Longevity', 'Molecular Manipulation'): 12,
#  ('Longevity', 'Regeneration'): 12,
#  ('Longevity', 'Omnilingualism'): 12,
#  ('Intelligence', 'Peak Human Condition'): 12,
#  ('Intelligence', 'Enhanced Smell'): 12,
#  ('Intelligence', 'Invisibility'): 12,
#  ('Intelligence', 'Vision - Microscopic'): 12,
#  ('Intelligence', 'Vision - Night'): 12,
#  ('Intelligence', 'Vision - X-Ray'): 12,
#  ('Super Strength', 'Intangibility'): 12,
#  ('Super Strength', 'Levitation'): 12,
#  ('Telepathy', 'Time Travel'): 12,
#  ('Telepathy', 'Invisibility'): 12,
#  ('Energy Blasts', 'Jump'): 12,
#  ('Energy Blasts', 'Time Manipulation'): 12,
#  ('Stamina', 'Phasing'): 12,
#  ('Stamina', 'Hypnokinesis'): 12,
#  ('Stamina', 'Time Travel'): 12,
#  ('Stamina', 'Invisibility'): 12,
#  ('Super Speed', 'Camouflage'): 12,
#  ('Super Speed', 'Heat Generation'): 12,
#  ('Super Speed', 'Light Control'): 12,
#  ('Super Speed', 'Sub-Mariner'): 12,
#  ('Animal Oriented Powers', 'Enhanced Senses'): 12,
#  ('Animal Oriented Powers', 'Wallcrawling'): 12,
#  ('Teleportation', 'Levitation'): 12,
#  ('Enhanced Senses', 'Immortality'): 12,
#  ('Enhanced Senses', 'Super Breath'): 12,
#  ('Telekinesis', 'Shapeshifting'): 12,
#  ('Telekinesis', 'Precognition'): 12,
#  ('Telekinesis', 'Energy Manipulation'): 12,
#  ('Energy Beams', 'Reflexes'): 12,
#  ('Energy Beams', 'Energy Constructs'): 12,
#  ('Energy Beams', 'Energy Manipulation'): 12,
#  ('Magic', 'Illusions'): 12,
#  ('Jump', 'Vision - Night'): 12,
#  ('Shapeshifting', 'Molecular Manipulation'): 12,
#  ('Immortality', 'Time Manipulation'): 12,
#  ('Camouflage', 'Reflexes'): 12,
#  ('Phasing', 'Energy Constructs'): 12,
#  ('Phasing', 'Invisibility'): 12,
#  ('Reflexes', 'Vision - Thermal'): 12,
#  ('Reflexes', 'Web Creation'): 12,
#  ('Invulnerability', 'Enhanced Smell'): 12,
#  ('Invulnerability', 'Time Manipulation'): 12,
#  ('Invulnerability', 'Invisibility'): 12,
#  ('Invulnerability', 'Vision - Thermal'): 12,
#  ('Invulnerability', 'Reality Warping'): 12,
#  ('Force Fields', 'Time Manipulation'): 12,
#  ('Psionic Powers', 'Mind Control'): 12,
#  ('Fire Resistance', 'Heat Resistance'): 12,
#  ('Vision - Telescopic', 'Vision - Heat'): 12,
#  ('Vision - Microscopic', 'Vision - Heat'): 12,
#  ('Agility', 'Dimensional Awareness'): 11,
#  ('Agility', 'Phasing'): 11,
#  ('Agility', 'Technopath/Cyberpath'): 11,
#  ('Agility', 'Time Manipulation'): 11,
#  ('Agility', 'Invisibility'): 11,
#  ('Agility', 'Vision - Microscopic'): 11,
#  ('Agility', 'Vision - Heat'): 11,
#  ('Agility', 'Vision - X-Ray'): 11,
#  ('Accelerated Healing', 'Animal Attributes'): 11,
#  ('Accelerated Healing', 'Substance Secretion'): 11,
#  ('Accelerated Healing', 'Heat Generation'): 11,
#  ('Accelerated Healing', 'Light Control'): 11,
#  ('Accelerated Healing', 'Levitation'): 11,
#  ('Accelerated Healing', 'Telepathy Resistance'): 11,
#  ('Accelerated Healing', 'Reality Warping'): 11,
#  ('Dimensional Awareness', 'Molecular Manipulation'): 11,
#  ('Dimensional Awareness', 'Time Travel'): 11,
#  ('Dimensional Awareness', 'Time Manipulation'): 11,
#  ('Dimensional Awareness', 'Reality Warping'): 11,
#  ('Cold Resistance', 'Flight'): 11,
#  ('Cold Resistance', 'Weapons Master'): 11,
#  ('Cold Resistance', 'Enhanced Smell'): 11,
#  ('Durability', 'Precognition'): 11,
#  ('Stealth', 'Camouflage'): 11,
#  ('Stealth', 'Psionic Powers'): 11,
#  ('Stealth', 'Telepathy Resistance'): 11,
#  ('Stealth', 'Sub-Mariner'): 11,
#  ('Energy Absorption', 'Heat Resistance'): 11,
#  ('Energy Absorption', 'Vision - Heat'): 11,
#  ('Flight', 'Enhanced Memory'): 11,
#  ('Flight', 'Empathy'): 11,
#  ('Flight', 'Natural Weapons'): 11,
#  ('Flight', 'Telepathy Resistance'): 11,
#  ('Flight', 'Omnilingualism'): 11,
#  ('Underwater breathing', 'Reflexes'): 11,
#  ('Marksmanship', 'Shapeshifting'): 11,
#  ('Marksmanship', 'Energy Manipulation'): 11,
#  ('Marksmanship', 'Vision - Thermal'): 11,
#  ('Weapons Master', 'Immortality'): 11,
#  ('Weapons Master', 'Vision - Night'): 11,
#  ('Animal Attributes', 'Wallcrawling'): 11,
#  ('Longevity', 'Weapon-based Powers'): 11,
#  ('Longevity', 'Phasing'): 11,
#  ('Longevity', 'Enhanced Memory'): 11,
#  ('Longevity', 'Natural Weapons'): 11,
#  ('Longevity', 'Illusions'): 11,
#  ('Intelligence', 'Enhanced Memory'): 11,
#  ('Intelligence', 'Enhanced Sight'): 11,
#  ('Intelligence', 'Super Breath'): 11,
#  ('Intelligence', 'Vision - Heat'): 11,
#  ('Super Strength', 'Matter Absorption'): 11,
#  ('Super Strength', 'Resurrection'): 11,
#  ('Super Strength', 'Reality Warping'): 11,
#  ('Telepathy', 'Phasing'): 11,
#  ('Telepathy', 'Hypnokinesis'): 11,
#  ('Telepathy', 'Mind Blast'): 11,
#  ('Telepathy', 'Reality Warping'): 11,
#  ('Energy Blasts', 'Vision - Thermal'): 11,
#  ('Energy Blasts', 'Reality Warping'): 11,
#  ('Duplication', 'Stamina'): 11,
#  ('Size Changing', 'Telekinesis'): 11,
#  ('Size Changing', 'Energy Manipulation'): 11,
#  ('Stamina', 'Dimensional Travel'): 11,
#  ('Stamina', 'Fire Resistance'): 11,
#  ('Super Speed', 'Omnilingualism'): 11,
#  ('Super Speed', 'Web Creation'): 11,
#  ('Weapon-based Powers', 'Power Suit'): 11,
#  ('Teleportation', 'Fire Control'): 11,
#  ('Teleportation', 'Invisibility'): 11,
#  ('Enhanced Senses', 'Enhanced Sight'): 11,
#  ('Enhanced Senses', 'Vision - Heat'): 11,
#  ('Telekinesis', 'Levitation'): 11,
#  ('Telekinesis', 'Time Travel'): 11,
#  ('Magic', 'Shapeshifting'): 11,
#  ('Jump', 'Web Creation'): 11,
#  ('Shapeshifting', 'Enhanced Hearing'): 11,
#  ('Shapeshifting', 'Wallcrawling'): 11,
#  ('Immortality', 'Time Travel'): 11,
#  ('Immortality', 'Reality Warping'): 11,
#  ('Astral Projection', 'Mind Control'): 11,
#  ('Fire Control', 'Invulnerability'): 11,
#  ('Reflexes', 'Energy Constructs'): 11,
#  ('Reflexes', 'Self-Sustenance'): 11,
#  ('Reflexes', 'Enhanced Sight'): 11,
#  ('Reflexes', 'Sub-Mariner'): 11,
#  ('Invulnerability', 'Natural Armor'): 11,
#  ('Invulnerability', 'Illusions'): 11,
#  ('Invulnerability', 'Omnilingualism'): 11,
#  ('Invulnerability', 'Vision - Night'): 11,
#  ('Force Fields', 'Precognition'): 11,
#  ('Force Fields', 'Reality Warping'): 11,
#  ('Psionic Powers', 'Energy Manipulation'): 11,
#  ('Mind Control', 'Illusions'): 11,
#  ('Enhanced Hearing', 'Heat Resistance'): 11,
#  ('Enhanced Hearing', 'Toxin and Disease Resistance'): 11,
#  ('Molecular Manipulation', 'Time Manipulation'): 11,
#  ('Natural Weapons', 'Enhanced Smell'): 11,
#  ('Enhanced Smell', 'Vision - Telescopic'): 11,
#  ('Enhanced Smell', 'Vision - Night'): 11,
#  ('Vision - Night', 'Vision - Infrared'): 11,
#  ('Vision - Infrared', 'Vision - Thermal'): 11,
#  ('Agility', 'Empathy'): 10,
#  ('Agility', 'Substance Secretion'): 10,
#  ('Agility', 'Power Suit'): 10,
#  ('Agility', 'Regeneration'): 10,
#  ('Agility', 'Light Control'): 10,
#  ('Agility', 'Web Creation'): 10,
#  ('Accelerated Healing', 'Invisibility'): 10,
#  ('Accelerated Healing', 'Sub-Mariner'): 10,
#  ('Dimensional Awareness', 'Size Changing'): 10,
#  ('Dimensional Awareness', 'Dimensional Travel'): 10,
#  ('Dimensional Awareness', 'Energy Manipulation'): 10,
#  ('Dimensional Awareness', 'Illusions'): 10,
#  ('Cold Resistance', 'Marksmanship'): 10,
#  ('Cold Resistance', 'Energy Blasts'): 10,
#  ('Cold Resistance', 'Jump'): 10,
#  ('Cold Resistance', 'Natural Weapons'): 10,
#  ('Cold Resistance', 'Vision - Telescopic'): 10,
#  ('Durability', 'Dimensional Travel'): 10,
#  ('Durability', 'Phasing'): 10,
#  ('Durability', 'Fire Control'): 10,
#  ('Durability', 'Substance Secretion'): 10,
#  ('Durability', 'Hypnokinesis'): 10,
#  ('Durability', 'Omnilingualism'): 10,
#  ('Stealth', 'Enhanced Sight'): 10,
#  ('Stealth', 'Vision - Thermal'): 10,
#  ...}

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
